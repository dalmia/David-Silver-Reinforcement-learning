# %%
import numpy as np
from lib.envs.blackjack import BlackjackEnv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-68e11f1e2708> in <module>()
#       1 import numpy as np
# ----> 2 from lib.envs.blackjack import BlackjackEnv
#
# ImportError: No module named lib.envs.blackjack
